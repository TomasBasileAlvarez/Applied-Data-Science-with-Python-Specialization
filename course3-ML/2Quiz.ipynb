# %% [markdown]
# # 2 Quiz
#
# ![image.png](attachment:image.png)

# %%
# b) Higher value of alpha makes less overfitting

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Decrease C and Gamma

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# classify a set of fruits as apples, bananas and lemons

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 10

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Lasso Regresion

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 0.1, 1 , 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Fig A = Ridge, B = Lasso

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 3

# 10

# %% [markdown]
# ![image.png](attachment:image.png)
